-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_bronze/bronze_sales_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_bronze/bronze_customer_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_bronze/bronze_product_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_silver/silver_sales_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_silver/silver_customer_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_silver/silver_product_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_gold/gold_sales_fact_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_gold/gold_customer_dim_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_gold/gold_product_dim_volume`;

-- %%
%python
# dbutils.notebook.exit("Truncated all tables in all layer except audits and quarantine tables.")

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/audit/audit_volume/etl_audit/`;

-- %%
%python
dbutils.notebook.exit("Truncated all tables in all layer except quarantine tables.")

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_quarantine/q_customer_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_quarantine/q_product_volume`;

-- %%
TRUNCATE TABLE delta.`/Volumes/retail_catalog/retail_quarantine/q_sales_volume`;
