-- %%
-- Sales view
CREATE OR REPLACE VIEW retail_catalog.retail_quarantine.vw_quarantine_sales AS
SELECT * 
FROM delta.`/Volumes/retail_catalog/retail_quarantine/q_sales_volume`;

-- Customer view
CREATE OR REPLACE VIEW retail_catalog.retail_quarantine.vw_quarantine_customer AS
SELECT * 
FROM delta.`/Volumes/retail_catalog/retail_quarantine/q_customer_volume`;

-- Product view
CREATE OR REPLACE VIEW retail_catalog.retail_quarantine.vw_quarantine_product AS
SELECT * 
FROM delta.`/Volumes/retail_catalog/retail_quarantine/q_product_volume`;
