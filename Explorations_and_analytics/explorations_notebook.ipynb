# %%
# Folder path
customer_folder = "/Volumes/retail_catalog/retail_source/source_customer_volume"
product_folder = "/Volumes/retail_catalog/retail_source/source_product_volume"
sales_folder = "/Volumes/retail_catalog/retail_source/source_sales_volume"


# Read all CSVs in folder
df_customers = spark.read.option("header", True).csv(customer_folder + "/*.csv")
df_products = spark.read.option("header", True).csv(product_folder + "/*.csv")
df_sales = spark.read.option("header", True).csv(sales_folder + "/*.csv")

# Show sample
df_customers.display(5)
df_products.display(5)
df_sales.display(5)

# %% [markdown]
# ### bronze

# %%
# %sql
select * from delta.`/Volumes/retail_catalog/audit/audit_volume/etl_audit/`;

# %%
# %sql
select * from delta.`/Volumes/retail_catalog/retail_bronze/bronze_product_volume`

# %%
# %sql
UPDATE delta.`/Volumes/retail_catalog/retail_bronze/bronze_product_volume`
SET _rescued_data = 'new data'
WHERE product_id ='PROD0007';

# %%
# %sql
select * from delta.`/Volumes/retail_catalog/retail_quarantine/q_product_volume`

# %%
# %sql
select * from delta.`/Volumes/retail_catalog/retail_gold/gold_product_dim_volume`;
