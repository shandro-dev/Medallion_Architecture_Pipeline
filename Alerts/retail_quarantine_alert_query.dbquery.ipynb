-- %%
SELECT
    (SELECT COUNT(*) FROM retail_catalog.retail_quarantine.vw_quarantine_sales)
  + (SELECT COUNT(*) FROM retail_catalog.retail_quarantine.vw_quarantine_customer)
  + (SELECT COUNT(*) FROM retail_catalog.retail_quarantine.vw_quarantine_product)
AS quarantine_row_count;
