-- %% [markdown]
-- SILVER OPTIMIZATION

-- %%
OPTIMIZE delta.`/Volumes/retail_catalog/retail_silver/silver_sales_volume` ZORDER BY (customer_id, product_id);

OPTIMIZE delta.`/Volumes/retail_catalog/retail_silver/silver_customer_volume` ZORDER BY(customer_id);

OPTIMIZE delta.`/Volumes/retail_catalog/retail_silver/silver_product_volume` ZORDER BY(product_id);

-- %%
VACUUM delta.`/Volumes/retail_catalog/retail_silver/silver_sales_volume` RETAIN 360 HOURS;
VACUUM delta.`/Volumes/retail_catalog/retail_silver/silver_customer_volume` RETAIN 360 HOURS;
VACUUM delta.`/Volumes/retail_catalog/retail_silver/silver_product_volume` RETAIN 360 HOURS;
