-- %% [markdown]
-- GOLD OPTIMIZATION

-- %%
OPTIMIZE delta.`/Volumes/retail_catalog/retail_gold/gold_sales_fact_volume` ZORDER BY (customer_id, product_id);

OPTIMIZE delta.`/Volumes/retail_catalog/retail_gold/gold_customer_dim_volume` ZORDER BY(customer_id);

OPTIMIZE delta.`/Volumes/retail_catalog/retail_gold/gold_product_dim_volume` ZORDER BY(product_id);

-- %%
VACUUM delta.`/Volumes/retail_catalog/retail_gold/gold_sales_fact_volume` RETAIN 360 HOURS;
VACUUM delta.`/Volumes/retail_catalog/retail_gold/gold_customer_dim_volume` RETAIN 360 HOURS;
VACUUM delta.`/Volumes/retail_catalog/retail_gold/gold_product_dim_volume` RETAIN 360 HOURS;
